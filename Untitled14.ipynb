doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T23:01:33+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0bb052","hashID":"096fb2bfc0c48015b43df461f4c44f6f","doorID":"W12 New Turnstile R In","accessDate":"2018-10-21T23:01:28+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0bb032","hashID":"134897b70fffba4473150e8501f4b949","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T23:00:06+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0bb031","hashID":"11065d6493f501ff018ab7cb89ed89a7","doorID":"W12 New Turnstile L Out","accessDate":"2018-10-21T22:59:58+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0bafbc","hashID":"e24dc5bbf0868104b2a938c71aca78cc","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:53:04+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0bafb7","hashID":"f98c39cb4512b4afd5c53df9a37e2672","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:52:53+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0bafa3","hashID":"20a733b22f308c77fff761f5a89188ec","doorID":"W12 New Turnstile L Out","accessDate":"2018-10-21T22:51:46+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0baf8b","hashID":"f7a299f10066ed4f316d4081ff30413c","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:50:14+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0baf7a","hashID":"3a5b6cc04bd7fb8cb10b42149df1fd0a","doorID":"W12 New Turnstile R In","accessDate":"2018-10-21T22:49:12+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0baf65","hashID":"fb7a00797fb7ed158013aeab20b5f3f2","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:47:40+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0baf60","hashID":"b1c6c94b55b4bd7ba7f2d03ae57bbacb","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:47:22+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0baf55","hashID":"b5f6833653f8b3a6d42eb5629cbb84d3","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:46:46+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0baf50","hashID":"55f48e83546d67a96096e44920747d52","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:46:29+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0baf4b","hashID":"22ffa643896cc7896d5cbf83ea0f9746","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:45:58+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0baf41","hashID":"6b88acd6cd94835f605d9cfe33e0a49c","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:45:33+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0baf2b","hashID":"92bb0b5d49a96dd6cf0cce23b82194df","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:44:25+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0baf29","hashID":"b033119294b3b5c933c25ba4781ed293","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:44:21+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0baf0f","hashID":"f8f0c3fb4edd5b7446e1f550426d10cf","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:42:59+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0baf07","hashID":"7af23c9da34240452e9ecf6806113338","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:42:45+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0baefb","hashID":"a40029023e268675897e02e7d5bb95da","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:42:07+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0baed4","hashID":"c54edaaae8766238d8633d7809cd77ec","doorID":"W12 New Turnstile R In","accessDate":"2018-10-21T22:40:45+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0baec0","hashID":"5c6b1b6884d5d5a3ecb1771099347536","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:40:14+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0bae89","hashID":"b8d8b91b974a4e2dc69af2befd23b581","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:37:08+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0bae77","hashID":"2fbb711d0690fecdceeccbb21dbe7f87","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:36:13+08:00","grantResult":"G"},{"_id":"5bcd4b846f517c795a0bae69","hashID":"11065d6493f501ff018ab7cb89ed89a7","doorID":"W12 New Turnstile L In ","accessDate":"2018-10-21T22:35:49+08:00","grantResult":"G"}]
print(data)
print(type(data))
#dumps 将数据转换成字符串
json.dump(data,file,ensure_ascii=False)
file.close()
file = open('test.json','r',encoding='utf-8')
s = json.load(file)
q =[]

def readjson(file):
    with open(file,'r',encoding='utf8') as fr:
        data1 = json.load(fr) # 用json中的load方法，将json串转换成字典
    return data1

def writeM():
    datas = readjson('test.json')
    title = ["_id", "hashID", "doorID", "accessDate", "grantResult"]
    book = xlwt.Workbook() # 创建一个excel对象
    sheet = book.add_sheet('Sheet1',cell_overwrite_ok=True) # 添加一个sheet页
    for i in range(len(title)): # 循环列
        sheet.write(0,i,title[i]) # 将title数组中的字段写入到0行i列中


    for i in range(len(datas)):#循环列表，取出每一个用户信息
        for j in range(len(title)):
            b = datas[i]
            message=b[j]
            q.append(message)
        l = [[k] for k in title]#将列表信息与title匹配的字段顺序输出
        for k1 in range(len(l)): #　循环列表
            sheet.write(1+i,k1,l[k1]) #　将信息写入第i+1行第k1列中
    book.save('demo.xls')#保存excel
if __name__ == '__main__':
    writeM()
